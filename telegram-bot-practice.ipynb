# %% [markdown]
# #Read data

# %%
import requests
base_url="https://api.telegram.org/bot1989994165:AAGibS-DoxnZyU2kfZTZqmIl9ZEfCQSRQyU/getUpdates"
param={
    "offset":"532355964",
    "limit":"1"
}
res=requests.get(base_url,data=param)
print(res.text)
# Out:
# {"ok":true,"result":[{"update_id":532355964,
# "message":{"message_id":5,"from":{"id":1164222476,"is_bot":false,"first_name":"Santhosh","last_name":"Nayak","username":"iamnyk7"},"chat":{"id":-587605047,"title":"test","type":"group","all_members_are_administrators":true},"date":1629048255,"text":"hi"}}]}

# %% [markdown]
# # Send Message

# %%
import requests
import time
base_url="https://api.telegram.org/bot1989994165:AAGibS-DoxnZyU2kfZTZqmIl9ZEfCQSRQyU/sendMessage"
# sending poor jokes xd
jocks=["uno mix unix","mithun *n =mithunrashi","I was playing badminton now then joined coaching now I play goodminotn","person near door =doormamu","what was pirates markscard = 7 C's"]

for joke in jocks:
    time.sleep(10)
    
    param={
        "chat_id":"-587605047",
        "text":joke
    }
    res=requests.get(base_url,data=param)
    print(res.text)
# Out:
# {"ok":true,"result":{"message_id":10,"from":{"id":1989994165,"is_bot":true,"first_name":"test","username":"hypecom_bot"},"chat":{"id":-587605047,"title":"test","type":"group","all_members_are_administrators":true},"date":1629051066,"text":"uno mix unix"}}
# {"ok":true,"result":{"message_id":11,"from":{"id":1989994165,"is_bot":true,"first_name":"test","username":"hypecom_bot"},"chat":{"id":-587605047,"title":"test","type":"group","all_members_are_administrators":true},"date":1629051076,"text":"mithun *n =mithunrashi"}}
# {"ok":true,"result":{"message_id":12,"from":{"id":1989994165,"is_bot":true,"first_name":"test","username":"hypecom_bot"},"chat":{"id":-587605047,"title":"test","type":"group","all_members_are_administrators":true},"date":1629051087,"text":"I was playing badminton now then joined coaching now I play goodminotn"}}
# ...

# %%
#Send Image
import requests
base_url="https://api.telegram.org/bot1989994165:AAGibS-DoxnZyU2kfZTZqmIl9ZEfCQSRQyU/sendPhoto"

param={
        "chat_id":"-587605047",
        "photo":"https://source.unsplash.com/user/erondu",
        "caption":"test"
    }
# send from local computer
# doc=open("loc",rb)
# files={
#     "photo/audio/doc/video":doc
# }
res=requests.get(base_url,data=param)
print(res.text)
# Out:
# {"ok":true,"result":{"message_id":21,"from":{"id":1989994165,"is_bot":true,"first_name":"test","username":"hypecom_bot"},"chat":{"id":-587605047,"title":"test","type":"group","all_members_are_administrators":true},"date":1629051793,"photo":[{"file_id":"AgACAgQAAxkDAAMVYRlbkUE_vAz3pPHWw11os48IIrEAArDgORtLHGQHm0H9sRSb7esBAAMCAANzAAMgBA","file_unique_id":"AQADsOA5G0scZAd4","file_size":1120,"width":90,"height":60},{"file_id":"AgACAgQAAxkDAAMVYRlbkUE_vAz3pPHWw11os48IIrEAArDgORtLHGQHm0H9sRSb7esBAAMCAANtAAMgBA","file_unique_id":"AQADsOA5G0scZAdy","file_size":18320,"width":320,"height":213},{"file_id":"AgACAgQAAxkDAAMVYRlbkUE_vAz3pPHWw11os48IIrEAArDgORtLHGQHm0H9sRSb7esBAAMCAAN4AAMgBA","file_unique_id":"AQADsOA5G0scZAd9","file_size":90623,"width":800,"height":533},{"file_id":"AgACAgQAAxkDAAMVYRlbkUE_vAz3pPHWw11os48IIrEAArDgORtLHGQHm0H9sRSb7esBAAMCAAN5AAMgBA","file_unique_id":"AQADsOA5G0scZAd-","file_size":149546,"width":1080,"height":720}],"caption":"test"}}

# %% [markdown]
# #Interactive

# %%
import requests
base_url="https://api.telegram.org/bot1989994165:AAGibS-DoxnZyU2kfZTZqmIl9ZEfCQSRQyU"

def read_message(ofset):
  param={
      "offset":ofset
  }
  res=requests.get(base_url+"/getUpdates",data=param)
  data= res.json()
  print(data)

  for res in data["result"]:
    if "hi" in res["message"]["text"]:
      send_message()
  if data["result"]:
      return data["result"][-1]["update_id"]+1



def send_message():
  param={
          "chat_id":"-587605047",
          "text":"hello brother"
      }
  res=requests.get(base_url+"/sendMessage",data=param)
  data= res.json()


if __name__ == "__main__":
  ofset=0
  while True:
    ofset=read_message(ofset)
# Out:
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 532355970, 'message': {'message_id': 30, 'from': {'id': 1164222476, 'is_bot': False, 'first_name': 'Santhosh', 'last_name': 'Nayak', 'username': 'iamnyk7'}, 'chat': {'id': -587605047, 'title': 'test', 'type': 'group', 'all_members_are_administrators': True}, 'date': 1629054082, 'text': 'hi'}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
# ...
